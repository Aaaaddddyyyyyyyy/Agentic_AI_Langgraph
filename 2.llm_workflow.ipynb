# %%
from langgraph.graph import StateGraph , START, END
from typing import TypedDict
from dotenv import load_dotenv
from langchain_groq import ChatGroq
import os

load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
load_dotenv()
# Out:
# True

# %%
model=ChatGroq( model="llama-3.3-70b-versatile")

# %%
# create a state 
class LLMState(TypedDict):
    question : str
    answer : str

# %%
def llm_qa(state: LLMState) -> LLMState:
    # extract question from state
    question= state['question']
    # form a prompt
    prompt= f'Answer the following question {question}?: '
    #ask questio to llm
    response= model.invoke(prompt).content
    # update the answer with state
    state['answer']=response
    return state

# %%
# create a graph
graph=StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

# compile the graph
workflow=graph.compile()

# %%
# execute the graph
 
initial_state={'question':'How to increase height of a male?'}
final_state=workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# Increasing height can be a challenging and complex process, especially after a certain age. However, I'll provide you with some tips and methods that may help. Keep in mind that these methods may not work for everyone, and results may vary.
#
# **For Teenagers and Young Adults (Under 25):**
#
# 1. **Hormone Regulation**: Ensure that your hormone levels, particularly growth hormone, are within the normal range. Consult a doctor if you have any concerns.
# 2. **Proper Nutrition**: Eat a balanced diet rich in calcium, vitamin D, and protein to support bone growth.
# 3. **Exercise Regularly**: Engage in exercises that promote bone growth, such as:
# 	* Stretching (e.g., yoga, Pilates)
# 	* Weightlifting (e.g., squats, lunges)
# 	* High-impact activities (e.g., jumping, running)
# 4. **Get Enough Sleep**: Adequate sleep (8-10 hours) is essential for growth hormone production and bone development.
# 5. **Maintain Good Posture**: Poor posture can make you appear shorter than you actually are. Practice good posture to maximize your height.
#
# **For Adults (Over 25):**
#
# 1. **Stretching and Exercise**: Continue to exercise regularly, focusing on stretches and activities that promote spinal flexibility and strength.
# 2. **Spinal Decompression**: Techniques like spinal decompression, inversion therapy, or hanging from a bar can help increase spinal length.
# 3. **Posture Correction**: Maintain good posture to prevent spinal compression and maximize your height.
# 4. **Shoe Lifts or Orthotics**: Consider using shoe lifts or orthotics to add height and support your feet and ankles.
# 5. **Surgery**: In some cases, surgery may be an option to correct spinal conditions or other issues that can affect height.
#
# **Additional Tips:**
#
# 1. **Avoid Smoking**: Smoking can stunt growth and reduce bone density.
# 2. **Limit Alcohol Consumption**: Excessive alcohol consumption can interfere with bone growth and density.
# 3. **Get Enough Vitamin D**: Vitamin D is essential for bone health and growth. Ensure you're getting enough through sunlight, diet, or supplements.
# 4. **Manage Stress**: Chronic stress can affect hormone production and bone growth. Engage in stress-reducing activities like meditation or yoga.
#
# **Important Notes:**
#
# 1. **Genetics**: Height is largely determined by genetics, so it's essential to have realistic expectations.
# 2. **Age Limitations**: After a certain age (usually around 25), the growth plates in your bones fuse, making it more challenging to increase height.
# 3. **Consult a Doctor**: If you're concerned about your height or have any underlying medical conditions, consult a doctor or a specialist (e.g., endocrinologist, orthopedic surgeon) for personalized advice.
#
# Remember, increasing height is not always possible, and results may vary. Focus on maintaining a healthy lifestyle, and if you're concerned about your height, consult a medical professional for guidance.
