# %%
! pip install langchain langchain-Groq langchain-community langgraph python-dotenv faiss-cpu pypdf
# Out:
# Requirement already satisfied: langchain in d:\langgraph\myenv\lib\site-packages (1.3.14)
# Requirement already satisfied: langchain-Groq in d:\langgraph\myenv\lib\site-packages (1.1.3)
# Requirement already satisfied: langchain-community in d:\langgraph\myenv\lib\site-packages (0.4.2)
# Requirement already satisfied: langgraph in d:\langgraph\myenv\lib\site-packages (1.2.10)
# Requirement already satisfied: python-dotenv in d:\langgraph\myenv\lib\site-packages (1.2.2)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.15.0-cp314-cp314-win_amd64.whl.metadata (7.8 kB)
# Collecting pypdf
#   Downloading pypdf-6.15.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in d:\langgraph\myenv\lib\site-packages (from langchain) (1.5.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\langgraph\myenv\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in d:\langgraph\myenv\lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in d:\langgraph\myenv\lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in d:\langgraph\myenv\lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in d:\langgraph\myenv\lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\langgraph\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\langgraph\myenv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\langgraph\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\langgraph\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in d:\langgraph\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in d:\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in d:\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in d:\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: certifi in d:\langgraph\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in d:\langgraph\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in d:\langgraph\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in d:\langgraph\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\langgraph\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\langgraph\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\langgraph\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in d:\langgraph\myenv\lib\site-packages (from langchain-Groq) (0.37.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\langgraph\myenv\lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\langgraph\myenv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in d:\langgraph\myenv\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in d:\langgraph\myenv\lib\site-packages (from langchain-community) (2.5.1)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\langgraph\myenv\lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in d:\langgraph\myenv\lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in d:\langgraph\myenv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\langgraph\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\langgraph\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in d:\langgraph\myenv\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.4)
# Using cached faiss_cpu-1.15.0-cp314-cp314-win_amd64.whl (16.5 MB)
# Downloading pypdf-6.15.0-py3-none-any.whl (378 kB)
# Installing collected packages: pypdf, faiss-cpu
#
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    -------------------- ------------------- 1/2 [faiss-cpu]
#    -------------------- ------------------- 1/2 [faiss-cpu]
#    -------------------- ------------------- 1/2 [faiss-cpu]
#    -------------------- ------------------- 1/2 [faiss-cpu]
#    -------------------- ------------------- 1/2 [faiss-cpu]
#    ---------------------------------------- 2/2 [faiss-cpu]
#
# Successfully installed faiss-cpu-1.15.0 pypdf-6.15.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/af/72/ce3067ac31e214a66388159f8462ddb8c13dd00170f24d555a1f1ae8ee91/pypdf-6.15.0-py3-none-any.whl.metadata
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.tools import tool
from langgraph.graph import StateGraph, START
from typing import Annotated, TypedDict
from langgraph.graph.message import add_messages
from langchain_core.messages import HumanMessage, BaseMessage
from langgraph.prebuilt import ToolNode, tools_condition

# %%
from langchain_huggingface import HuggingFaceEmbeddings     # embeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 5019.85it/s]

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model='llama-3.3-70b-versatile')

# %%
loader=PyPDFLoader("final rl.pdf")
docs=loader.load()

# %%
len(docs)
# Out:
# 18
